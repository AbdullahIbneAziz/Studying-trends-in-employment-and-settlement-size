# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Importing dataset

# %%
data=pd.read_csv('sgdata.csv')

# %%
data
# Out:
#              ID  Sex                                     Marital status  Age  \
# 0     100000001    0                                             single   67
# 1     100000002    1  non-single (divorced / separated / married / w...   22
# 2     100000003    0                                             single   49
# 3     100000004    0                                             single   45
# 4     100000005    0                                             single   53
# ...         ...  ...                                                ...  ...
# 1995  100001996    1                                             single   47
# 1996  100001997    1  non-single (divorced / separated / married / w...   27
# 1997  100001998    0                                             single   31
# 1998  100001999    1  non-single (divorced / separated / married / w...   24
# 1999  100002000    0                                             single   25
#
# ...

# %%
data.shape
# Out:
# (2000, 8)

# %%
data.isnull().sum()
# Out:
# ID                 0
# Sex                0
# Marital status     0
# Age                0
# Education          0
# Income             0
# Occupation         0
# Settlement size    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               2000 non-null   int64
#  1   Sex              2000 non-null   int64
#  2   Marital status   2000 non-null   object
#  3   Age              2000 non-null   int64
#  4   Education        2000 non-null   object
#  5   Income           2000 non-null   int64
#  6   Occupation       2000 non-null   object
#  7   Settlement size  2000 non-null   int64
# dtypes: int64(5), object(3)
# memory usage: 125.1+ KB

# %%
data.describe()
# Out:
#                  ID          Sex          Age         Income  Settlement size
# count  2.000000e+03  2000.000000  2000.000000    2000.000000      2000.000000
# mean   1.000010e+08     0.457000    35.909000  120954.419000         0.739000
# std    5.774946e+02     0.498272    11.719402   38108.824679         0.812533
# min    1.000000e+08     0.000000    18.000000   35832.000000         0.000000
# 25%    1.000005e+08     0.000000    27.000000   97663.250000         0.000000
# 50%    1.000010e+08     0.000000    33.000000  115548.500000         1.000000
# 75%    1.000015e+08     1.000000    42.000000  138072.250000         1.000000
# max    1.000020e+08     1.000000    76.000000  309364.000000         2.000000

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### EDA

# %%
data['Marital status'].value_counts().plot(kind='pie', autopct='%.2f', figsize=(10,6), colors=['blue', 'orange'])
plt.title('Marital Status Distribution')
plt.show()

# %%
data['Sex'].value_counts()
# Out:
# Sex
# 0    1086
# 1     914
# Name: count, dtype: int64

# %%
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
plt.title('Sex Distribution')
sns.countplot(x=data['Sex'], palette='viridis')
plt.subplot(1,2,2)
plt.title('Education Distribution')
sns.countplot(x=data['Education'])
plt.show()

# %%
plt.figure(figsize=(9,6))
plt.title('Sex vs Education')
sns.countplot(x=data['Sex'], hue=data['Education'])
plt.show()

# %%
plt.figure(figsize=(9,6))
plt.title('Sex vs Marital Status')
sns.countplot(x=data['Sex'], hue=data['Marital status'], palette='Reds')
plt.show()

# %%
plt.figure(figsize=(9,6))
plt.title('Occupation vs Education')
sns.countplot(x=data['Occupation'], hue=data['Education'])
plt.xticks(rotation=80)
plt.show()

# %%
plt.figure(figsize=(9,6))
plt.title('Settlement size vs Sex')
sns.countplot(x=data['Settlement size'], hue=data['Sex'], palette='magma')
plt.show()

# %%
plt.figure(figsize=(9,6))
plt.title('Scatterplot Age, Income vs Sex')
sns.scatterplot(x=data['Age'], y=data['Income'], s=100, alpha=1, palette='magma', hue=data['Sex'])
plt.show()

# %%
plt.figure(figsize=(9,6))
plt.title('Distribution of Age')
sns.histplot(x=data['Age'], kde=True, color='blue')
plt.show()

# %%
plt.figure(figsize=(9,6))
plt.title('Distribution of Income')
sns.histplot(x=data['Income'], kde=True, color='purple')
plt.show()

# %%
data.columns
# Out:
# Index(['ID', 'Sex', 'Marital status', 'Age', 'Education', 'Income',
#        'Occupation', 'Settlement size'],
#       dtype='object')
